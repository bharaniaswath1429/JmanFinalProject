# %%
# %pip install prettytable
# %pip install xgboost
# %pip install imbalanced-learn
# %pip install pandas numpy seaborn matplotlib scikit-learn
# Out:
# Requirement already satisfied: prettytable in c:\users\bharaniaswathr\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: wcwidth in c:\users\bharaniaswathr\appdata\roaming\python\python312\site-packages (from prettytable) (0.2.13)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xgboost in c:\users\bharaniaswathr\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imbalanced-learn in c:\users\bharaniaswathr\anaconda3\lib\site-packages (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\bharaniaswathr\anaconda3\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\bharaniaswathr\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: seaborn in c:\users\bharaniaswathr\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\bharaniaswathr\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: scikit-learn in c:\users\bharaniaswathr\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bharaniaswathr\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\bharaniaswathr\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bharaniaswathr\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\bharaniaswathr\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np  
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from imblearn.over_sampling import SMOTE
from prettytable import PrettyTable
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
import time
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("modified_employee_data.csv", encoding = "ISO-8859-1", engine="python")

# %% [markdown]
# ## EDA

# %%
data.head()
# Out:
#    employee_id        designation  no_of_trainings  length_of_service  \
# 0        65438       Data Analyst                1                  8
# 1        65141  Software Engineer                1                  4
# 2         7513    DevOps Engineer                1                  7
# 3         2542     Data Scientist                2                 10
# 4        48945            Manager                1                  2
#
#    avg_training_score  is_promoted
# 0                49.0            0
# 1                60.0            0
# 2                50.0            0
# 3                50.0            0
# 4                73.0            0

# %%
data.tail()
# Out:
#        employee_id          designation  no_of_trainings  length_of_service  \
# 54803         3030  Principle Architect                1                 17
# 54804        74592  Principle Architect                1                  6
# 54805        13918                Admin                1                  3
# 54806        13614      DevOps Engineer                1                  2
# 54807        51526      DevOps Engineer                1                  5
#
#        avg_training_score  is_promoted
# 54803                78.0            0
# 54804                56.0            0
# 54805                79.0            0
# 54806                 NaN            0
# 54807                49.0            0

# %%
data.columns
# Out:
# Index(['employee_id', 'designation', 'no_of_trainings', 'length_of_service',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
data.shape
# Out:
# (54808, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         54808 non-null  int64
#  1   designation         54808 non-null  object
#  2   no_of_trainings     54808 non-null  int64
#  3   length_of_service   54808 non-null  int64
#  4   avg_training_score  52248 non-null  float64
#  5   is_promoted         54808 non-null  int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.5+ MB

# %%
data.dtypes
# Out:
# employee_id             int64
# designation            object
# no_of_trainings         int64
# length_of_service       int64
# avg_training_score    float64
# is_promoted             int64
# dtype: object

# %%
np.sum(data.isnull().any(axis=1))
# Out:
# 2560

# %%
data.isnull().sum()
# Out:
# employee_id              0
# designation              0
# no_of_trainings          0
# length_of_service        0
# avg_training_score    2560
# is_promoted              0
# dtype: int64

# %%
data.describe()
# Out:
#         employee_id  no_of_trainings  length_of_service  avg_training_score  \
# count  54808.000000     54808.000000       54808.000000        52248.000000
# mean   39195.830627         1.253011           5.865512           63.712238
# std    22586.581449         0.609264           4.265094           13.521910
# min        1.000000         1.000000           1.000000           39.000000
# 25%    19669.750000         1.000000           3.000000           51.000000
# 50%    39225.500000         1.000000           5.000000           60.000000
# 75%    58730.500000         1.000000           7.000000           77.000000
# max    78298.000000        10.000000          37.000000           99.000000
#
#         is_promoted
# count  54808.000000
# mean       0.085170
# std        0.279137
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# #### Numeric features distrubution

# %%
data.hist(figsize=(20,20),bins = 20, color="#6C63FF")
plt.title("Numeric Features Distribution")
plt.show()

# %% [markdown]
# #### designation distribution

# %%
sns.countplot(data= data, x = "designation")
plt.show()

# %%
data["designation"].value_counts().head(10).plot(kind = 'pie', autopct='%1.1f%%', figsize=(10, 10)).legend()

# %% [markdown]
# #### no_of_trainings distribution

# %%
sns.countplot(data= data, x = "no_of_trainings")
plt.show()

# %%
data["no_of_trainings"].value_counts().head(10).plot(kind = 'pie', autopct='%1.1f%%', figsize=(10, 10), startangle=0).legend()

# %%
data["length_of_service"].value_counts().head(10).plot(kind = 'pie', autopct='%1.1f%%', figsize=(10, 10), startangle=0).legend()

# %% [markdown]
# #### avg_training_score distribution

# %%
data["avg_training_score"].value_counts().head(10).plot(kind = 'pie', autopct='%1.1f%%', figsize=(10, 10), startangle=0).legend()

# %% [markdown]
# #### is_promoted distribution

# %%
sns.countplot(data= data, x = "is_promoted")
plt.show()

# %%
data["is_promoted"].value_counts().head(7).plot(kind = 'pie', autopct='%1.1f%%', figsize=(10, 10), startangle=0).legend()

# %%
data["is_promoted"].value_counts()
# Out:
# is_promoted
# 0    50140
# 1     4668
# Name: count, dtype: int64

# %% [markdown]
# #### Distribution of promoted employees ratio across different no_of_trainings

# %%
plt.rcParams['figure.figsize'] = [10, 5]
score_bin = pd.crosstab(data.no_of_trainings,data.is_promoted,normalize='index')
score_bin.plot.bar(stacked=True)
plt.legend(title='is_promoted',loc='upper left',bbox_to_anchor=(1, 0.5))

# %% [markdown]
# #### Distribution of promoted employees ratio across different length_of_service

# %%
plt.rcParams['figure.figsize'] = [10, 5]
score_bin = pd.crosstab(data.length_of_service,data.is_promoted,normalize='index')
score_bin.plot.bar(stacked=True)
plt.legend(title='is_promoted',loc='upper left',bbox_to_anchor=(1, 0.5))

# %% [markdown]
# #### Distribution of promoted employees ratio across different avg_training_score

# %%
plt.rcParams['figure.figsize'] = [10, 5]
score_bin = pd.crosstab(data.avg_training_score,data.is_promoted,normalize='index')
score_bin.plot.bar(stacked=True)
plt.legend(title='is_promoted',loc='upper left',bbox_to_anchor=(1, 0.5))

# %% [markdown]
# #### Pearson Correlation of Features

# %%
pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform(data['designation'])
data['designation'] = encpro

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data.corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %% [markdown]
# #### no_of_trainings plot with is_promoted

# %%
g = sns.FacetGrid(data, col='is_promoted')
g.map(plt.hist, 'no_of_trainings', bins=20)

# %% [markdown]
# #### length_of_service plot with is_promoted

# %%
g = sns.FacetGrid(data, col='is_promoted')
g.map(plt.hist, 'length_of_service', bins=20)

# %% [markdown]
# #### avg_training_score plot with is_promoted

# %%
g = sns.FacetGrid(data, col='is_promoted')
g.map(plt.hist, 'avg_training_score', bins=20)

# %% [markdown]
# ## Data Pre-Processing

# %%
data=data.drop_duplicates()

# %%
data.isnull().sum()
# Out:
# employee_id              0
# designation              0
# no_of_trainings          0
# length_of_service        0
# avg_training_score    2560
# is_promoted              0
# dtype: int64

# %%
data['avg_training_score'] = data['avg_training_score'].fillna(data['avg_training_score'].mode()[0])

# %%
data.isnull().sum()
# Out:
# employee_id           0
# designation           0
# no_of_trainings       0
# length_of_service     0
# avg_training_score    0
# is_promoted           0
# dtype: int64

# %% [markdown]
# ## Building Model

# %%
X=data.drop(columns=['is_promoted', 'employee_id'])
y=data['is_promoted']

X = pd.get_dummies(X)

X = X.apply(pd.to_numeric, errors='coerce')

smt = SMOTE()
X_up, y_up = smt.fit_resample(X, y)

# %%
sns.countplot(data= data, x = y_up)
# Out:
# <Axes: xlabel='is_promoted', ylabel='count'>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_up, y_up, test_size=0.3, random_state=2)

models = {
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "XGBoost": XGBClassifier(verbosity=0),
    "Logistic Regression": LogisticRegression(max_iter=1000)
}

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    
    # Evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print(f"\nModel: {name}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")
    print(classification_report(y_test, y_pred))

    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Confusion Matrix for {name}')
    plt.grid(False)
    plt.show()

    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure(figsize=(10, 6))
    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random guessing
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()
# Out:
# Model: Random Forest
# Accuracy: 0.80
# Precision: 0.79
# Recall: 0.82
# F1 Score: 0.80
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.80     15105
#            1       0.79      0.82      0.80     14979
#
#     accuracy                           0.80     30084
#    macro avg       0.80      0.80      0.80     30084
# weighted avg       0.80      0.80      0.80     30084
# Model: Decision Tree
# Accuracy: 0.81
# Precision: 0.80
# Recall: 0.82
# F1 Score: 0.81
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81     15105
#            1       0.80      0.82      0.81     14979
#
#     accuracy                           0.81     30084
#    macro avg       0.81      0.81      0.81     30084
# weighted avg       0.81      0.81      0.81     30084
# Model: XGBoost
# Accuracy: 0.72
# Precision: 0.72
# Recall: 0.70
# F1 Score: 0.71
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72     15105
#            1       0.72      0.70      0.71     14979
#
#     accuracy                           0.72     30084
#    macro avg       0.72      0.72      0.72     30084
# weighted avg       0.72      0.72      0.72     30084
# Model: Logistic Regression
# Accuracy: 0.65
# Precision: 0.65
# Recall: 0.61
# F1 Score: 0.63
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66     15105
#            1       0.65      0.61      0.63     14979
#
#     accuracy                           0.65     30084
#    macro avg       0.65      0.65      0.64     30084
# weighted avg       0.65      0.65      0.64     30084

# %%
# Get coefficients for Logistic Regression
log_reg = models['Logistic Regression']
coefficients = log_reg.coef_[0]

# Create a DataFrame for coefficients
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': coefficients
}).sort_values(by='Coefficient', key=abs, ascending=False)

print("\nTop 5 Coefficients for Logistic Regression:")
print(coef_df.head(5))
# Out:
# Top 5 Coefficients for Logistic Regression:
#               Feature  Coefficient
# 3  avg_training_score     0.654667
# 1     no_of_trainings    -0.458151
# 2   length_of_service    -0.092506
# 0         designation    -0.085733

# %%
def predict_promotion(model, employee_data):
    employee_df = pd.DataFrame([employee_data])
    employee_encoded = pd.get_dummies(employee_df)
    
    # Add missing columns that exist in the training data
    for col in X.columns:
        if col not in employee_encoded.columns:
            employee_encoded[col] = 0
    
    # Align the columns to match the training data
    employee_encoded = employee_encoded[X.columns]
    
    # Standardize the numeric features
    employee_encoded = scaler.transform(employee_encoded)
    
    # Predict promotion
    prediction = model.predict(employee_encoded)
    return "Promoted" if prediction[0] == 1 else "Not Promoted"

# %%
# Example new employee data
new_employee = {
    'designation': 'Sales & Marketing',
    'no_of_trainings': 5,
    'length_of_service': 2,
    'avg_training_score': 40.0,
}

# Making predictions with all models
for name, model in models.items():
    print(f"\nPrediction for new employee using {name}: {predict_promotion(model, new_employee)}")
# Out:
# Prediction for new employee using Random Forest: Not Promoted
#
# Prediction for new employee using Decision Tree: Not Promoted
#
# Prediction for new employee using XGBoost: Not Promoted
#
# Prediction for new employee using Logistic Regression: Not Promoted

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
start = time.time()
RN=RandomForestClassifier()
Grid_RN = GridSearchCV(estimator=RN, param_grid=param_grid, cv= 2)
Grid_RN.fit(X_train, y_train)
end = time.time()
RF_time1=end-start

# %%
Grid_RN.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'n_estimators': 200}

# %%
print('Execution time is ', RF_time1)
# Out:
# Execution time is  567.3997905254364

# %%
y_pred = Grid_RN.predict(X_test) #getting predictions on the trained model
rn1=round(recall_score(y_test, y_pred, average='micro'),3)
print('Recall',round(recall_score(y_test, y_pred, average='micro'),3),'%')
# Out:
# Recall 0.676 %

# %% [markdown]
# ## Downsampled

# %%
data["is_promoted"].value_counts()
# Out:
# is_promoted
# 0    50140
# 1     4668
# Name: count, dtype: int64

# %%
promoted=data[data["is_promoted"]==1]
not_promoted=data[data["is_promoted"]==0] 
not_promoted = not_promoted.sample(len(promoted), random_state=42) 
downsample = pd.concat([promoted, not_promoted]).reset_index(drop=True)
downsample['avg_training_score'].unique()
# Out:
# array([50., 51., 47., 58., 84., 78., 49., 65., 60., 69., 63., 57., 90.,
#        86., 72., 92., 89., 88., 70., 56., 48., 94., 93., 95., 83., 75.,
#        62., 68., 96., 64., 52., 59., 76., 46., 87., 74., 91., 82., 55.,
#        73., 81., 85., 99., 77., 54., 80., 67., 53., 66., 71., 97., 79.,
#        44., 98., 43., 42., 41., 40.])

# %%
sns.countplot(data= data, x = downsample['is_promoted'])
# Out:
# <Axes: xlabel='is_promoted', ylabel='count'>

# %%
X_train, X_test, y_train, y_test = train_test_split(downsample.drop(columns=['is_promoted', 'employee_id']), downsample['is_promoted'], test_size=0.3, random_state=2)

# %%
models1 = {
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "XGBoost": XGBClassifier(verbosity=0),
    "Logistic Regression": LogisticRegression(max_iter=1000)
}

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


for name, model in models1.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    
    # Evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print(f"\nModel: {name}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")
    print(classification_report(y_test, y_pred))

    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Confusion Matrix for {name}')
    plt.grid(False)
    plt.show()

    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure(figsize=(10, 6))
    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random guessing
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()
# Out:
# Model: Random Forest
# Accuracy: 0.57
# Precision: 0.59
# Recall: 0.55
# F1 Score: 0.57
#               precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58      1373
#            1       0.59      0.55      0.57      1428
#
#     accuracy                           0.57      2801
#    macro avg       0.57      0.57      0.57      2801
# weighted avg       0.57      0.57      0.57      2801
# Model: Decision Tree
# Accuracy: 0.54
# Precision: 0.56
# Recall: 0.47
# F1 Score: 0.51
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57      1373
#            1       0.56      0.47      0.51      1428
#
#     accuracy                           0.54      2801
#    macro avg       0.55      0.55      0.54      2801
# weighted avg       0.55      0.54      0.54      2801
# Model: XGBoost
# Accuracy: 0.60
# Precision: 0.62
# Recall: 0.55
# F1 Score: 0.58
#               precision    recall  f1-score   support
#
#            0       0.58      0.65      0.61      1373
#            1       0.62      0.55      0.58      1428
#
#     accuracy                           0.60      2801
#    macro avg       0.60      0.60      0.60      2801
# weighted avg       0.60      0.60      0.60      2801
# Model: Logistic Regression
# Accuracy: 0.63
# Precision: 0.65
# Recall: 0.59
# F1 Score: 0.62
#               precision    recall  f1-score   support
#
#            0       0.61      0.67      0.64      1373
#            1       0.65      0.59      0.62      1428
#
#     accuracy                           0.63      2801
#    macro avg       0.63      0.63      0.63      2801
# weighted avg       0.63      0.63      0.63      2801

# %%
# Get coefficients for Logistic Regression
log_reg = models['Logistic Regression']
coefficients = log_reg.coef_[0]

# Create a DataFrame for coefficients
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': coefficients
}).sort_values(by='Coefficient', key=abs, ascending=False)

print("\nTop 5 Coefficients for Logistic Regression:")
print(coef_df.head(5))
# Out:
# Top 5 Coefficients for Logistic Regression:
#               Feature  Coefficient
# 3  avg_training_score     0.654667
# 1     no_of_trainings    -0.458151
# 2   length_of_service    -0.092506
# 0         designation    -0.085733

# %%
def predict_promotion1(model, employee_data):
    employee_df = pd.DataFrame([employee_data])
    employee_encoded = pd.get_dummies(employee_df)
    
    # Add missing columns that exist in the training data
    for col in X.columns:
        if col not in employee_encoded.columns:
            employee_encoded[col] = 0
    
    # Align the columns to match the training data
    employee_encoded = employee_encoded[X.columns]
    
    # Standardize the numeric features
    employee_encoded = scaler.transform(employee_encoded)
    
    # Predict promotion
    prediction = model.predict(employee_encoded)
    return "Promoted" if prediction[0] == 1 else "Not Promoted"

# %%
# Example new employee data
new_employee = {
    'designation': 'admin',
    'no_of_trainings': 1,
    'length_of_service': 9,
    'avg_training_score': 65.0,
}

# Making predictions with all models
for name, model in models1.items():
    print(f"\nPrediction for new employee using {name}: {predict_promotion(model, new_employee)}")
# Out:
# Prediction for new employee using Random Forest: Not Promoted
#
# Prediction for new employee using Decision Tree: Promoted
#
# Prediction for new employee using XGBoost: Promoted
#
# Prediction for new employee using Logistic Regression: Promoted

# %% [markdown]
# ## Hyperparameter Tuning using Grid Search

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
start = time.time()
RN=RandomForestClassifier()
Grid_RN = GridSearchCV(estimator=RN, param_grid=param_grid, cv= 2)
Grid_RN.fit(X_train, y_train)
end = time.time()
RF_time1=end-start

# %%
Grid_RN.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'n_estimators': 500}

# %%
print('Execution time is ', RF_time1)
# Out:
# Execution time is  82.51600193977356

# %%
y_pred = Grid_RN.predict(X_test) #getting predictions on the trained model
rn1=round(recall_score(y_test, y_pred, average='micro'),3)
print('Recall',round(recall_score(y_test, y_pred, average='micro'),3),'%')
# Out:
# Recall 0.632 %
